# %%
import pandas as pd
import numpy as np
from matplotlib.backends.backend_pdf import PdfPages

# %%
#abengoa=pd.read_csv('../spanish-stocks-historical-data/abengoa.csv')

# %%
#acciona=pd.read_csv('../spanish-stocks-historical-data/acciona.csv')

# %%
#acerinox=pd.read_csv('../spanish-stocks-historical-data/acerinox.csv')

# %%
#acs=pd.read_csv('../spanish-stocks-historical-data/acs.csv')

# %%
#atresmedia=pd.read_csv('../spanish-stocks-historical-data/atresmedia.csv')

# %%
#banco_sabadell=pd.read_csv('../spanish-stocks-historical-data/banco_sabadell.csv')

# %%
#bankinter=pd.read_csv('../spanish-stocks-historical-data/bankinter.csv')

# %%
#bbva=pd.read_csv('../spanish-stocks-historical-data/bbva.csv')

# %%
#bme=pd.read_csv('../spanish-stocks-historical-data/bme.csv')

# %%
#caixabank=pd.read_csv('../spanish-stocks-historical-data/caixabank.csv')

# %%
#colonial=pd.read_csv('../spanish-stocks-historical-data/colonial.csv')

# %%
#enagas=pd.read_csv('../spanish-stocks-historical-data/enagas.csv')

# %%
#fcc=pd.read_csv('../spanish-stocks-historical-data/fcc.csv')

# %%
#ferrovial=pd.read_csv('../spanish-stocks-historical-data/ferrovial.csv')

# %%
#grifols=pd.read_csv('../spanish-stocks-historical-data/grifols.csv')

# %%
#iberdrola=pd.read_csv('../spanish-stocks-historical-data/iberdrola.csv')

# %%
#inditex=pd.read_csv('../spanish-stocks-historical-data/inditex.csv')

# %%
#indra=pd.read_csv('../spanish-stocks-historical-data/indra.csv')

# %%
#mapfre=pd.read_csv('../spanish-stocks-historical-data/mapfre.csv')

# %%
#mediaset=pd.read_csv('../spanish-stocks-historical-data/mediaset.csv')

# %%
#naturgy=pd.read_csv('../spanish-stocks-historical-data/naturgy.csv')

# %%
#red_electrica=pd.read_csv('../spanish-stocks-historical-data/red_electrica.csv')

# %%
#repsol=pd.read_csv('../spanish-stocks-historical-data/repsol.csv')

# %%
#sacyr=pd.read_csv('../spanish-stocks-historical-data/sacyr.csv')

# %%
#santander=pd.read_csv('../spanish-stocks-historical-data/santander.csv')

# %%
#siemens_gamesa=pd.read_csv('../spanish-stocks-historical-data/siemens_gamesa.csv')

# %%
#telefonica=pd.read_csv('../spanish-stocks-historical-data/telefonica.csv')

# %%
df=pd.read_csv('../spanish-stocks-historical-data/abengoa.csv')

# %%
companies=["abengoa","acciona","acerinox","acs","atresmedia","banco_sabadell","bankinter","bbva","bme","caixabank","colonial","enagas","fcc","ferrovial","grifols","iberdrola","inditex","indra","mapfre","mediaset","naturgy","red_electrica","repsol","sacyr","santander","siemens_gamesa","telefonica"]

# %%
lista_dfs = []
for company in companies:
    df_temp = pd.read_csv('../spanish-stocks-historical-data/{0}.csv'.format(company))
    df_temp['company'] = company
    print(df_temp.shape)
    lista_dfs.append(df_temp)
    
df_total = pd.concat(lista_dfs)
display(df_total)
#print(df_total.shape)
# Out:
# (2604, 7)
# (2924, 7)
# (2604, 7)
# (2605, 7)
# (2602, 7)
# (2605, 7)
# (2605, 7)
# (6216, 7)
# (2605, 7)
# (2571, 7)
# (2243, 7)
# (2605, 7)
# (2605, 7)
# (3041, 7)
# (2605, 7)
# (2604, 7)
# (2605, 7)
# (2605, 7)
# (2605, 7)
# (2607, 7)
# (2605, 7)
# (2606, 7)
# (3141, 7)
# (2607, 7)
# (6217, 7)
# (3063, 7)
# (6214, 7)
#             Date   Close    High     Low    Open     Volume     company
# 0     2009-02-11  12.970  13.040  12.970  12.980          0     abengoa
# 1     2009-02-12  12.400  13.080  12.400  13.080          0     abengoa
# 2     2009-02-13  12.720  12.930  12.720  12.800          0     abengoa
# 3     2009-02-16  12.560  12.800  12.560  12.590          0     abengoa
# 4     2009-02-17  11.900  12.670  11.900  12.430          0     abengoa
# 5     2009-02-18  11.850  12.210  11.850  12.120          0     abengoa
# 6     2009-02-19  12.130  12.130  11.910  12.100          0     abengoa
# 7     2009-02-20  11.610  11.910  11.610  11.850          0     abengoa
# ...

# %%
df_total.company.value_counts()
# Out:
# santander         6217
# bbva              6216
# telefonica        6214
# repsol            3141
# siemens_gamesa    3063
# ferrovial         3041
# acciona           2924
# mediaset          2607
# sacyr             2607
# red_electrica     2606
# banco_sabadell    2605
# bankinter         2605
# indra             2605
# naturgy           2605
# bme               2605
# enagas            2605
# mapfre            2605
# inditex           2605
# grifols           2605
# acs               2605
# fcc               2605
# iberdrola         2604
# acerinox          2604
# atresmedia        2602
# caixabank         2571
# colonial          2243
# Name: company, dtype: int64

# %%
def companies(companies):
    lista_dfs = []
    for company in companies:
        df_temp = pd.read_csv('../spanish-stocks-historical-data/{0}.csv'.format(company))
        df_temp['company'] = company
        print(df_temp.shape)
        lista_dfs.append(df_temp)
    
    df_total = pd.concat(lista_dfs)
    print(df_total)
    return def_total
a=companies(companies)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-0e61b1665903> in <module>
#      10     print(df_total)
#      11     return def_total
# ---> 12 a=companies(companies)
#
# <ipython-input-33-0e61b1665903> in companies(companies)
#       1 def companies(companies):
#       2     lista_dfs = []
# ----> 3     for company in companies:
#       4         df_temp = pd.read_csv('../spanish-stocks-historical-data/{0}.csv'.format(company))
#       5         df_temp['company'] = company
#
# TypeError: 'function' object is not iterable

# %%
import requests
from bs4 import BeautifulSoup

# %%
'''url="https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20130428&end=20180216"
res=requests.get(url)
soup=BeautifulSoup(res.text,"html.parser")
titles=soup.find_all('th')

column_names=[]
for e in titles:
    column_names.append(e.text)
#print(column_names[:7])

data=[]
datos=soup.find_all('td')
print(datos)'''
'''
for i in datos:
    data.append(i.text)
for i in range(len(data)): 
    x = data[i:i+7]
    print(x)
    
# print(data)
MAX_ROW = 1756
date=data[0:MAX_ROW:7]
open1=data[1:MAX_ROW:7]
high=data[2:MAX_ROW:7]
low=data[3:MAX_ROW:7]
close1=data[4:MAX_ROW:7]
volume=data[5:MAX_ROW:7]
market_cap=data[6:MAX_ROW:7]
name=[]

for i in range(MAX_ROW):
    name.append("bitcoin")
    '''
# Out:
# '\nfor i in datos:\n    data.append(i.text)\nfor i in range(len(data)): \n    x = data[i:i+7]\n    print(x)\n    \n# print(data)\nMAX_ROW = 1756\ndate=data[0:MAX_ROW:7]\nopen1=data[1:MAX_ROW:7]\nhigh=data[2:MAX_ROW:7]\nlow=data[3:MAX_ROW:7]\nclose1=data[4:MAX_ROW:7]\nvolume=data[5:MAX_ROW:7]\nmarket_cap=data[6:MAX_ROW:7]\nname=[]\n\nfor i in range(MAX_ROW):\n    name.append("bitcoin")\n    '

# %%
url="https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20130428&end=20180216"
res=requests.get(url)
soup=BeautifulSoup(res.text,"html.parser")
rows = soup.find_all('tr', {'class': 'text-right'})

column_names=[]
for e in rows:
    pass
#print(column_names[:7])

# %%
rows[1].find_all('td')
# Out:
# [<td class="text-left">Feb 15, 2018</td>,
#  <td data-format-fiat="" data-format-value="9488.3203125">9488.32</td>,
#  <td data-format-fiat="" data-format-value="10234.7998047">10234.80</td>,
#  <td data-format-fiat="" data-format-value="9395.58007812">9395.58</td>,
#  <td data-format-fiat="" data-format-value="10166.4003906">10166.40</td>,
#  <td data-format-market-cap="" data-format-value="9062540288.0">9,062,540,288</td>,
#  <td data-format-market-cap="" data-format-value="1.71477807437e+11">171,477,807,437</td>]

# %%
lst=[]
for i in rows:
    lst.append(i.text.replace("\n"," ").split(" "))
date=[]
open1=[]
high=[]
low=[]
close1=[]
volume=[]
market_cap=[]

for i in lst:
    date.append(" ".join(i[1:4]))
    open1.append(i[4])
    high.append(i[5])
    low.append(i[6])
    close1.append(i[7])
    volume.append(i[8])
    market_cap.append(i[9])

name=[]
for i in range(len(lst)):
    name.append("bitcoin")

# %%
bitcoin=pd.DataFrame(list(zip(date, close1, high, low, open1, volume, name)), 
               columns =['Date', 'Close','High','Low','Open','Volume', 'company']) 
bitcoin
# Out:
#               Date     Close      High       Low      Open          Volume  \
# 0     Feb 16, 2018  10233.90  10324.10   9824.82  10135.70   7,296,159,744
# 1     Feb 15, 2018  10166.40  10234.80   9395.58   9488.32   9,062,540,288
# 2     Feb 14, 2018   9494.63   9518.54   8599.92   8599.92   7,909,819,904
# 3     Feb 13, 2018   8598.31   8958.47   8455.41   8926.72   5,696,719,872
# 4     Feb 12, 2018   8926.57   8985.92   8141.43   8141.43   6,256,439,808
# 5     Feb 11, 2018   8129.97   8616.13   7931.10   8616.13   6,122,189,824
# 6     Feb 10, 2018   8621.90   9122.55   8295.47   8720.08   7,780,960,256
# 7     Feb 09, 2018   8736.98   8736.98   7884.71   8271.84   6,784,820,224
# 8     Feb 08, 2018   8265.59   8558.77   7637.86   7637.86   9,346,750,464
# 9     Feb 07, 2018   7621.30   8509.11   7236.79   7755.49   9,169,280,000
# 10    Feb 06, 2018   7754.00   7850.70   6048.26   7051.75  13,999,800,320
# ...

# %%
#webscraping

months={"Jan":"01","Feb":"02","Mar":"03","Apr":"04","May":"05","Jun":"06","Jul":"07","Aug":"08","Sep":"09","Oct":"10","Nov":"11","Dec":"12"}
def fun(x):
    for e in months.items():
        if e[0] in str(x):
            fecha=str(x).replace(e[0],e[1]).replace(",","").replace(" ","-")
            return fecha[6:] + "-" + fecha[0:5]
    
bitcoin["Date"]=bitcoin["Date"].apply(fun)
bitcoin["Date"]
# Out:
# 0       2018-02-16
# 1       2018-02-15
# 2       2018-02-14
# 3       2018-02-13
# 4       2018-02-12
# 5       2018-02-11
# 6       2018-02-10
# 7       2018-02-09
# 8       2018-02-08
# 9       2018-02-07
# 10      2018-02-06
# 11      2018-02-05
# 12      2018-02-04
# 13      2018-02-03
# 14      2018-02-02
# 15      2018-02-01
# 16      2018-01-31
# 17      2018-01-30
# 18      2018-01-29
# 19      2018-01-28
# 20      2018-01-27
# 21      2018-01-26
# 22      2018-01-25
# 23      2018-01-24
# 24      2018-01-23
# 25      2018-01-22
# 26      2018-01-21
# 27      2018-01-20
# 28      2018-01-19
# 29      2018-01-18
#            ...
# 1726    2013-05-27
# 1727    2013-05-26
# 1728    2013-05-25
# 1729    2013-05-24
# 1730    2013-05-23
# 1731    2013-05-22
# 1732    2013-05-21
# 1733    2013-05-20
# 1734    2013-05-19
# 1735    2013-05-18
# 1736    2013-05-17
# 1737    2013-05-16
# 1738    2013-05-15
# 1739    2013-05-14
# 1740    2013-05-13
# 1741    2013-05-12
# ...

# %%
df_final=pd.concat([df_total, bitcoin], ignore_index=True)
display(df_final)
# Out:
#              Date   Close    High     Low    Open Volume  company
# 0      2009-02-11   12.97   13.04   12.97   12.98      0  abengoa
# 1      2009-02-12    12.4   13.08    12.4   13.08      0  abengoa
# 2      2009-02-13   12.72   12.93   12.72    12.8      0  abengoa
# 3      2009-02-16   12.56    12.8   12.56   12.59      0  abengoa
# 4      2009-02-17    11.9   12.67    11.9   12.43      0  abengoa
# 5      2009-02-18   11.85   12.21   11.85   12.12      0  abengoa
# 6      2009-02-19   12.13   12.13   11.91    12.1      0  abengoa
# 7      2009-02-20   11.61   11.91   11.61   11.85      0  abengoa
# 8      2009-02-25   10.49   10.84   10.49   10.73      0  abengoa
# 9      2009-02-26    11.1    11.1   10.63   10.63      0  abengoa
# 10     2009-02-27   10.25   10.81   10.25   10.81      0  abengoa
# 11     2009-03-06    8.61    9.08    8.61    9.08      0  abengoa
# 12     2009-03-09    8.66    8.81    8.66    8.81      0  abengoa
# ...

# %%
'''url="https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20130428&end=20180216"
res=requests.get(url)
soup=BeautifulSoup(res.text,"html.parser")
rows = soup.find_all('tr', {'class': 'text-right'})

column_names=[]
for e in rows:
    pass
#print(column_names[:7])

lst=[]
for i in rows:
    lst.append(i.text.replace("\n"," ").split(" "))
date=[]
open1=[]
high=[]
low=[]
close1=[]
volume=[]
market_cap=[]

for i in lst:
    date.append(" ".join(i[1:4]))
    open1.append(i[4])
    high.append(i[5])
    low.append(i[6])
    close1.append(i[7])
    volume.append(i[8])
    market_cap.append(i[9])

name=[]
for i in range(len(lst)):
    name.append("bitcoin")
    
    
bitcoin=pd.DataFrame(list(zip(date, close1, high, low, open1, volume, name)), 
               columns =['Date', 'Close','High','Low','Open','Volume', 'company']) 
bitcoin


months={"Jan":"01","Feb":"02","Mar":"03","Apr":"04","May":"05","Jun":"06","Jul":"07","Aug":"08","Sep":"09","Oct":"10","Nov":"11","Dec":"12"}
"""for i in bitcoin["Date"].values():
    for e in months:
        i.replace(e,get.values(e))"""
def fun(x):
    for e in months.items():
        if e[0] in str(x):
            fecha=str(x).replace(e[0],e[1]).replace(",","").replace(" ","-")
            return fecha[6:] + "-" + fecha[0:5]
    
bitcoin["Date"]=bitcoin["Date"].apply(fun)
bitcoin["Date"]'''
# Out:
# 'url="https://coinmarketcap.com/currencies/bitcoin/historical-data/?start=20130428&end=20180216"\nres=requests.get(url)\nsoup=BeautifulSoup(res.text,"html.parser")\nrows = soup.find_all(\'tr\', {\'class\': \'text-right\'})\n\ncolumn_names=[]\nfor e in rows:\n    pass\n#print(column_names[:7])\n\nlst=[]\nfor i in rows:\n    lst.append(i.text.replace("\n"," ").split(" "))\ndate=[]\nopen1=[]\nhigh=[]\nlow=[]\nclose1=[]\nvolume=[]\nmarket_cap=[]\n\nfor i in lst:\n    date.append(" ".join(i[1:4]))\n    open1.append(i[4])\n    high.append(i[5])\n    low.append(i[6])\n    close1.append(i[7])\n    volume.append(i[8])\n    market_cap.append(i[9])\n\nname=[]\nfor i in range(len(lst)):\n    name.append("bitcoin")\n    \n    \nbitcoin=pd.DataFrame(list(zip(date, close1, high, low, open1, volume, name)), \n               columns =[\'Date\', \'Close\',\'High\',\'Low\',\'Open\',\'Volume\', \'company\']) \nbitcoin\n\n\nmonths={"Jan":"01","Feb":"02","Mar":"03","Apr":"04","May":"05","Jun":"06","Jul":"
# ...

# %%
#funciona
from matplotlib import pyplot as plt

df_final['Date'] = pd.to_datetime(df_final['Date'])
comp=input("Introduce the name of the company you would like to plot:")
df_subset=df_final[df_final["company"]==comp]
plt.plot(df_subset['Date'], df_subset['Close'])

plt.xlabel('Date')  
plt.ylabel('Close Price')  
plt.title('Simple time series plot for HDFC')

# %%
#velas japonesas
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

import pandas as pd
from datetime import datetime

# %%
import plotly 
plotly.tools.set_credentials_file(username='lgarciaco1', api_key='AcJ6Vmo1ko0vhudVWrfJ')

companies=["acciona","acerinox","acs","atresmedia","banco_sabadell","bankinter","bbva","bme","caixabank","colonial","enagas","fcc","ferrovial","grifols","iberdrola","inditex","indra","mapfre","mediaset","naturgy","red_electrica","repsol","sacyr","santander","siemens_gamesa","telefonica","bitcoin"]
comp=input("Introduce the name of the company you would like to plot:")
comp.lower()
if comp in companies:
    df_subset=df_final[df_final["company"]==comp]
    start_date = input("Introduce start date:")
    end_date=input("Introduce end date:")
    df_subset5 = df_subset[(df_subset['Date'] > start_date) & (df_subset['Date'] <= end_date)]

else:
    print("Error, the selected company is not included.")
    

trace = go.Candlestick(x=df_subset5['Date'],
                open=df_subset5['Open'],
                high=df_subset5['High'],
                low=df_subset5['Low'],
                close=df_subset5['Close'])
data = [trace]
py.iplot(data, filename='simple_candlestick')
# Out:
# Introduce the name of the company you would like to plot:naturgy
# Introduce start date:2018-01-01
# Introduce end date:2019-01-01
# High five! You successfully sent some data to your account on plotly. View your plot in your browser at https://plot.ly/~lgarciaco1/0 or inside your plot.ly account where it is named 'simple_candlestick'
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~lgarciaco1/0.embed" height="525px" width="100%"></iframe>

# %%
'''
1. columnas implicadas a float
2. drop nulos de estas columnas
3. map
'''

df_final['Open'] = df_final['Open'].astype(float)
df_final["Close"] = df_final["Close"].astype(float)

# %%
df_final["daily change"] = list(map(lambda x,y: x/y, df_final['Open'],df_final['Close']))
df_final["daily change"].plot(grid=True)

from matplotlib import pyplot as plt


df_final['Date'] = pd.to_datetime(df_final['Date'])
comp=input("Introduce the name of the company you would like to plot:")
df_subset=df_final[df_final["company"]==comp]
plt.plot(df_subset['Date'], df_subset['daily change'])

plt.xlabel('Date')  
plt.ylabel('Close Price')  
plt.title('Simple time series plot for HDFC')
# Out:
# Introduce the name of the company you would like to plot:naturgy
# Text(0.5, 1.0, 'Simple time series plot for HDFC')
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7f56af3742f0> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~/.local/lib/python3.6/site-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     126         for f_mgr in cls.get_all_fig_managers():
#     127             if force or f_mgr.canvas.figure.stale:
# --> 128                 f_mgr.canvas.draw_idle()
#     129
#     130 atexit.register(Gcf.destroy_all)
#
# ...

# %%
#incremento porcentual
df_final['Date'] = pd.to_datetime(df_final['Date'])

num=2
lst1=[]
for i in range(num):
    comp1=input("Introduce the name of company {0}:".format(i+1))
    lst1.append(comp1)
print(lst1)
subsetDataFrame = df_final[df_final['company'].isin(lst1) ]

lst2=[]
for i in range(num):
    dfprueba=subsetDataFrame[subsetDataFrame["company"]==lst1[i]]
    lst2.append(dfprueba[["Date","Close","company"]])
    
df_subset3 = pd.merge(*lst2, on="Date")
    
start_date = input("Introduce start date:")
end_date=input("Introduce end date:")
df_subset4 = df_subset3[(df_subset3['Date'] >= start_date) & (df_subset3['Date'] <= end_date)]
# Out:
# Introduce the name of company 1:naturgy
# Introduce the name of company 2:telefonica
# ['naturgy', 'telefonica']
# Introduce start date:2018-01-01
# Introduce end date:2019-01-01

# %%
df_subset4['Close_x'] = df_subset4['Close_x'].astype(float)
y=df_subset4.Close_x.values[0]
df_subset4["return_x"] = df_subset4["Close_x"].apply(lambda x: x/y)

df_subset4['Close_y'] = df_subset4['Close_y'].astype(float)
z=df_subset4.Close_y.values[0]
df_subset4["return_y"] = df_subset4["Close_y"].apply(lambda x: x/z)
# Out:
# /home/luis/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/luis/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/luis/.local/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df_subset4['Date'], df_subset4['return_x'])
plt.plot(df_subset4["Date"],df_subset4['return_y'])

plt.xlabel('Date')  
plt.ylabel('% Change')  


plt.show()

# %%
#rolling mean

import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import pyEX as p
import matplotlib.dates as mdates

# %%
df_final['Date'] = pd.to_datetime(df_final['Date'])
comp=input("Introduce the name of the company you would like to plot:")
df_subset=df_final[df_final["company"]==comp]
lst2=[]
for i in range(2):
    window=int(input("Introduce window number {0}:".format(i+1)))
    lst2.append(window)
    
start_date = input("Introduce start date:")
end_date=input("Introduce end date:")
df_subset1 = df_subset[(df_subset['Date'] > start_date) & (df_subset['Date'] <= end_date)]

rolling_mean = df_subset1["Close"].rolling(window=lst2[0]).mean()
rolling_mean2 = df_subset1["Close"].rolling(window=lst2[1]).mean()

plt.plot(df_subset1["Date"], df_subset1["Close"], label='AMD')
plt.plot(df_subset1["Date"], rolling_mean, label='AMD 20 Day SMA', color='orange')
plt.plot(df_subset1["Date"], rolling_mean2, label='AMD 50 Day SMA', color='magenta')
plt.legend(loc='upper left')
plt.show()
# Out:
# Introduce the name of the company you would like to plot:naturgy
# Introduce window number 1:20
# Introduce window number 2:50
# Introduce start date:2018-01-01
# Introduce end date:2019-01-01
